# %% [markdown]
# Ouvrir ce notebook dans :
# <a href="https://colab.research.google.com/github/joanglaunes/deep_learning_image/blob/main/TP_DINO_init.ipynb" target="_blank">Google Colab</a>
# ou
# <a href="https://rosenblatt.ens.math-info.univ-paris5.fr/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fjoanglaunes%2Fdeep_learning_image&urlpath=tree%2Fdeep_learning_image%2FTP_DINO_init.ipynb&branch=main" target="_blank">Rosenblatt</a>

# %% [markdown]
# ## TP - Classification KNN sur les features de DINO
#
# 1) Utiliser la commande suivante dans le dossier du code de DINO pour effectuer une classification aux plus proches voisins (KNN) sur les features de DINO calculés sur les images du dataset "imagenette2":<br>
# `python eval_knn.py --data_path ~/data_M2MMAS/imagenette2 --dump_features .`<br>
# Ceci enregistre également des fichiers `trainfeat.pth`, `trainlabels.pth`, `testfeat.pth`, `testlabels.pth` contenant les features et labels des données train et test du dataset.
# 2) Charger ces fichiers dans ce notebook et utiliser la méthode de classification aux plus proches voisins de la librairie `scikit-learn` pour reproduire les résultats du code précédent.
# 3) Modifier le code `eval_knn.py` pour qu'il enregistre également des fichiers `trainimages.pth` et `testimages.pth` contenant les images du dataset.
# 4) Effectuer une classification KNN sur les images brutes du dataset. Que constate-t-on ?
# 5) Recommencer les expériences sur les features et les images du dataset MNIST, à partir des fichiers de ce dossier `/home/jupyter-glaunes/data_M2MMAS/features_MNIST`. Commenter les résultats.
